# %%
import pandas as pd
import numpy as np
from statistics import mean

# %%
from IPython.display import Image
Image(filename='F:\\Documents\\Day python tutorial\\Questions\\July_31_2021_Questions.png')

# %%
pop = np.random.normal(100,15,25000)
school = np.random.choice(pop, size=5000)

# %%
output = []
for i in range(9900):
    claim = np.random.choice(school, size=30)
    output.append(mean(claim))
print(sum(n > 112 for n in output))
pd.DataFrame(output).describe()
# Out:
# 0
#                  0
# count  9900.000000
# mean     99.800330
# std       2.730195
# min      89.760007
# 25%      97.922069
# 50%      99.778859
# 75%     101.661745
# max     110.119200
